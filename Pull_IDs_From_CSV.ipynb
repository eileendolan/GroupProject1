# %%
import pandas as pd

# %%
movie_data = pd.read_csv('U.S. Released Movies_ 1972-2016.csv', encoding='latin-1')

movie_data.head()
# Out:
#    Position      Const    Created   Modified Description  \
# 0         1  tt0110912  4/23/2013  4/23/2013         NaN
# 1         2  tt1872181  4/23/2013  4/23/2013         NaN
# 2         3  tt0111161  4/23/2013  4/23/2013         NaN
# 3         4  tt0076759  4/23/2013  4/23/2013         NaN
# 4         5  tt0088763  4/23/2013  4/23/2013         NaN
#
#                       Title                                    URL Title Type  \
# 0              Pulp Fiction  https://www.imdb.com/title/tt0110912/      movie
# 1  The Amazing Spider-Man 2  https://www.imdb.com/title/tt1872181/      movie
# 2  The Shawshank Redemption  https://www.imdb.com/title/tt0111161/      movie
# 3                 Star Wars  https://www.imdb.com/title/tt0076759/      movie
# 4        Back to the Future  https://www.imdb.com/title/tt0088763/      movie
#
#    IMDb Rating  Runtime (mins)    Year                              Genres  \
# ...

# %%
movie_data['Release Date'] = pd.to_datetime(movie_data['Release Date'])

# %%
time_data = movie_data.loc[movie_data['Release Date'] >= '01/01/2010']
IMDB_IDs = time_data['Const']
